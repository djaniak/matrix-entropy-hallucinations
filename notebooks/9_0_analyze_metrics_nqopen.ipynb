# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append("../")

# %%
import os
import torch

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = ""

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device
# Out:
# device(type='cpu')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set_style("whitegrid")

# %%
from pathlib import Path

from hallucinations.utils.metric_loader import get_activation_dirs, load_model_answers, compute_model_results

dataset = "nq_open"
data_dir = Path(f"../data/activations/{dataset}")
activations_dirs = get_activation_dirs(data_dir, dataset=dataset)
model_answers = load_model_answers(activations_dirs)
model_results = compute_model_results(model_answers)
# Out:
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 20543.38it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 8236.46it/s]
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 12320.19it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 5621.01it/s]
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 12939.45it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 6326.28it/s]
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 10910.15it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 5792.29it/s]
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 11091.77it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 6316.40it/s]
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 11023.79it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 8345.24it/s]
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 18880.00it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 9453.83it/s]
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 19603.51it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 8472.82it/s]
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 11716.57it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 5915.99it/s]
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 9510.53it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 5885.25it/s]
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 6712.77it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 4790.74it/s]
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 7096.53it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 4905.60it/s]
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 8314.02it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 5485.27it/s]
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 6356.29it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 4726.05it/s]
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 13956.53it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 6576.87it/s]
# Evaluating SQUAD metrics: 100%|██████████| 3610/3610 [00:00<00:00, 14573.20it/s]
# Evaluating ROUGE metrics: 100%|██████████| 3610/3610 [00:00<00:00, 9151.92it/s]

# %%
from tqdm.notebook import tqdm
from hallucinations.utils.metric_loader import load_model_metrics_as_df

METRICS = ["erank", "diff_erank", "diff_erank_pretrain", "logdet"]
id_cols = ["model", "temperature", "squad_f1", "squad_exact_match", "rougeL_fmeasure", "rougeL_precision", "rougeL_recall"]

dfs_melted = {}

for metric in tqdm(METRICS):
    df_metrics = load_model_metrics_as_df(model_results, metric_type=metric)
    df_melted = df_metrics.melt(
        id_vars=id_cols,
        value_vars=[f"{metric}_layer_{i}" for i in range(33)],
        var_name="layer",
        value_name=metric
    )
    df_melted["correct"] = df_melted["rougeL_fmeasure"].apply(lambda x: 1 if x >= 0.3 else 0)
    df_melted["layer"] = df_melted["layer"].str.extract("(\d+)").astype(int)
    dfs_melted[metric] = df_melted
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\d'
# <>:18: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_2414355/298131807.py:18: SyntaxWarning: invalid escape sequence '\d'
#   df_melted["layer"] = df_melted["layer"].str.extract("(\d+)").astype(int)
#   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# # Plot metric values for NQ Open

# %%
for metric in METRICS:
    g = sns.FacetGrid(
        data=dfs_melted[metric],
        col="temperature",
        height=5,
        aspect=1.5
    )

    g.map_dataframe(
        sns.lineplot,
        x="layer",
        y=metric,
        hue="model",
        style="correct", 
        alpha=0.7,
        errorbar="sd",
    )

    g.set_axis_labels("Layer", metric)

    # Move legend next to plot by adjusting bbox_to_anchor coordinates
    g.add_legend(bbox_to_anchor=(1.05, 0.5), loc='center left', title="Model")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# - The difference in effective rank (ERank) between correctly and incorrectly answered samples is analyzed for Mistral and LLaMA-3B models.
# - **The effect of temperatures:**
#   - **At low temperatures:**
#     - For some models (e.g., Mistral 7B, LLaMA 3B), there is virtually no noticeable difference in ERank between correct and incorrect samples.
#   - **At high temperatures:**
#     - A visible difference in ERank emerges between the two sample types, highlighting greater separation in these cases.
# - **The effect of token masking:**
#   - **With token masking:**
#     - The ERank values for incorrect and correct samples diverge earlier in the network.
#     - This indicates that earlier layers are better at distinguishing between correct and incorrect samples when masking is applied.
#   - **Without token masking:**
#     - The divergence occurs later in the layers.
#
# The impact of these differences will be quantified later using the Area Under the Receiver Operating Characteristic (AUROC) metric.

# %% [markdown]
# ---

# %%
df1 = dfs_melted["nq_open"]["diff_erank"]
df1 = df1[df1["model"] == "llama_3.1_8b_instruct"]
df1["diff_model"] = "untrained"

df2 = dfs_melted["nq_open"]["diff_erank_pretrain"].rename(columns={"diff_erank_pretrain": "diff_erank"})
df2["diff_model"] = "pretrained"

df_plot = pd.concat([df1, df2], axis=0)
# Out:
# /tmp/ipykernel_2014521/3895672275.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["diff_model"] = "untrained"

# %%
g = sns.FacetGrid(
    data=df_plot[df_plot["diff_erank"] != 0.],
    col="temperature",
    height=5,
    aspect=1.5
)

g.map_dataframe(
    sns.lineplot,
    x="layer",
    y="diff_erank",
    hue="diff_model",
    style="correct", 
    alpha=0.7,
    errorbar="sd",
)

g.set_axis_labels("Layer", "Difference in erank")
g.add_legend(bbox_to_anchor=(1.05, 0.5), loc='center left', title="Model")

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Effective rank, similar to matrix entropy, measures the compression of a representation.
# 2. The level of compression depends on whether special tokens are included in the computation.
# 3. In the middle layers, hidden states exhibit lower or similar effective rank in the instruct model compared to the pretrained model.
# 4. In the final layers, the pretrained model tends to have a lower effective rank, especially when considering token-masked hidden states.

# %% [markdown]
# # Compute AUROC per layer

# %%
from sklearn.metrics import roc_auc_score

model_names = ['llama_3.2_3b_instruct', 'llama_3.1_8b_instruct', 'llama_3.1_8b', 'mistral_0.3_7b_instruct', 'phi_3.5_mini_instruct']

auroc_results = []

for metric in METRICS:
    df_plot = dfs_melted[metric].dropna(subset=[metric])
    df_plot = df_plot[df_plot[metric] != 0.]

    for model in model_names:
        for temperature in ["low", "high"]:
            model_data = df_plot[(df_plot["model"] == model) & (df_plot["temperature"] == temperature)]
            
            for layer in model_data["layer"].unique():
                layer_data = model_data[model_data["layer"] == layer]
                
                if layer_data["correct"].nunique() < 2:
                    continue
                
                if metric == "diff_erank":
                    auroc = roc_auc_score(layer_data["correct"], layer_data[metric])
                else:
                    auroc = 1 - roc_auc_score(layer_data["correct"], layer_data[metric])
                
                auroc_results.append({
                    "model": model,
                    "layer": layer,
                    "auroc": auroc,
                    "temperature": temperature,
                    "metric": metric
                })

# %% [markdown]
# ## Plot AUROC per each metric

# %%
auroc_df = pd.DataFrame(auroc_results)

fig, axes = plt.subplots(nrows=len(METRICS), ncols=1, figsize=(10, 4 * len(METRICS)), sharey=True)

for ax, metric in zip(axes, METRICS):
    sns.lineplot(
        data=auroc_df[(auroc_df["auroc"] != 0.5) & (auroc_df["metric"] == metric)],
        x="layer",
        y="auroc", 
        hue="model",
        style="temperature",
        marker="o",
        markevery=4,
        ax=ax
    )
    ax.set_title(metric)
    ax.set_xlabel("Layer")
    ax.set_ylabel("AUROC" if ax == axes[0] else "")
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot AUROC per each model

# %%
auroc_df = pd.DataFrame(auroc_results)

fig, axes = plt.subplots(nrows=len(set(auroc_df["model"])), ncols=1, figsize=(10, 4 * len(set(auroc_df["model"]))), sharey=True)

for ax, model in zip(axes, sorted(auroc_df["model"].unique())):
    sns.lineplot(
        data=auroc_df[(auroc_df["auroc"] != 0.5) & (auroc_df["model"] == model)],
        x="layer",
        y="auroc",
        hue="metric",
        style="temperature", 
        marker="o",
        markevery=4,
        ax=ax
    )
    ax.set_title(model)
    ax.set_xlabel("Layer")
    ax.set_ylabel("AUROC" if ax == axes[0] else "")
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
max_auroc_df = auroc_df.groupby(['model', 'metric'])['auroc'].max().reset_index()


plt.figure(figsize=(10, 4))
sns.barplot(
    data=max_auroc_df,
    x='model',
    y='auroc',
    hue='metric',
    palette='deep'
)

plt.title("Maximum AUROC Across Layers by Model")
plt.xlabel("Model")
plt.ylabel("Max AUROC")
plt.xticks(rotation=45, ha='right')
plt.legend(title="Temperature", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# - **The hallucination detection abilities are not correlated with accuracy in the downstream task:**
#   - Mistral achieves the highest AUROC in detecting hallucinated samples, even though its performance in the task (e.g., QA accuracy/F1) is not the best. LLaMA performs better in accuracy/F1 but worse in hallucination detection.
# - **Token masking improves hallucination detection:**
#   - Masking allows for better and earlier detection of hallucinated samples.
# - **The effect of temperature:**
#   - Temperature significantly impacts hallucination detection for some models.
# - **LLaMA (pretrained) struggles with hallucination detection:**
#   - Pretrained LLaMA (before instruction tuning) cannot effectively detect hallucinations and also performs poorly in answering tasks.
